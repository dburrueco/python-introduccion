# %%
pi = 3.141592

# %%
print(pi + 1)
# Out:
# 4.141592

# %%
a = 5
print(a)
# Out:
# 5

# %%
a = "Python"
print(a)
# Out:
# Python

# %%
print(a)
# Out:
# Python

# %%
a
# Out:
# 'Python'

# %%
3 * 2
# Out:
# 6

# %%
3 * 2
b = 6

# %%
a = 1
A = 2
print(a)
# Out:
# 1

# %% [markdown]
# ### snake_case

# %%
altura_edificio = 8

# %%
alturaEdificio = 8
