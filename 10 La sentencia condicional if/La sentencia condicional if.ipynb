# %%
temp = 54

# %%
temp > 50
# Out:
# True

# %%
if temp > 50:
    print("Alerta")
# Out:
# Alerta

# %%
if temp > 50:
    pass

# %%
if temp > 50:
    print("Alerta")
    print("Temperatura elevada")
# Out:
# Alerta
# Temperatura elevada

# %%
temp = 27
if temp > 50:
    print("Alerta")
print("Temperatura evaluada")
# Out:
# Temperatura evaluada

# %%
if temp > 50:
    print("Alerta")
if temp <= 50:
    print("Temperatura correcta")
# Out:
# Temperatura correcta

# %%
if temp > 50:
    print("Alerta")
else:
    print("Temperatura correcta")
# Out:
# Temperatura correcta

# %%
temp = 45
if temp > 50:
    print("Temperatura excesiva")
elif temp > 40:
    print("Temperatura elevada")
elif temp > 30:
    print("Temperatura correcta")
# Out:
# Temperatura elevada

# %%
temp = 15
if temp > 50:
    print("Temperatura excesiva")
elif temp > 40:
    print("Temperatura elevada")
elif temp > 30:
    print("Temperatura correcta")
else:
    print("Temperatura demasiado baja")
# Out:
# Temperatura demasiado baja

# %%
temp_correcta = True
if temp_correcta == True:
    print("Temperatura correcta")
# Out:
# Temperatura correcta

# %%
if temp_correcta:
    print("Temperatura correcta")
# Out:
# Temperatura correcta

# %%
temp = 45
press = 4
if (temp > 40) and (press > 3):
    print("Alerta")
# Out:
# Alerta
