# %% [markdown]
# ### Números enteros

# %%
a = -7

# %%
type(a)
# Out:
# int

# %%
type(-7)
# Out:
# int

# %% [markdown]
# ### Números reales

# %%
b = 3.14
type(b)
# Out:
# float

# %%
c = 4.0
type(c)
# Out:
# float

# %% [markdown]
# ### Números complejos

# %%
d = -2 + 6j

# %%
type(d)
# Out:
# complex

# %% [markdown]
# ### Textos

# %%
e = "Python"

# %%
type(e)
# Out:
# str

# %%
e = 'Python'

# %%
e = """Python"""
type(e)
# Out:
# str

# %%
e = """Python
for
Data Science"""
print(e)
# Out:
# Python
# for
# Data Science

# %% [markdown]
# ### Booleano

# %%
f = True
type(f)
# Out:
# bool

# %%
f = False
type(f)
# Out:
# bool

# %%
5 > 3
# Out:
# True

# %%
type(5 > 3)
# Out:
# bool
