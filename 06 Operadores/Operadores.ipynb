# %%
5 + 7
# Out:
# 12

# %%
2 ** 3
# Out:
# 8

# %%
pow(2,3)
# Out:
# 8

# %% [markdown]
# ### Operadores aritméticos

# %%
5 + 6
# Out:
# 11

# %%
2.0 + 3.0
# Out:
# 5.0

# %%
(2 + 5j) + (3 - 6j)
# Out:
# (5-1j)

# %%
5 + 3.0
# Out:
# 8.0

# %%
5.0 + (1 - 2j)
# Out:
# (6-2j)

# %%
3 - 5.0
# Out:
# -2.0

# %%
3 * 5
# Out:
# 15

# %%
6 / 2
# Out:
# 3.0

# %%
14 // 3
# Out:
# 4

# %%
14 % 3
# Out:
# 2

# %%
6 % 2
# Out:
# 0

# %%
7 % 2
# Out:
# 1

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# ### Operadores de comparación

# %%
3 == 5
# Out:
# False

# %%
3 == 3.0
# Out:
# True

# %%
4 != 5
# Out:
# True

# %%
5 < 3
# Out:
# False

# %%
5 > 3
# Out:
# True

# %%
4 <= 4
# Out:
# True

# %%
7 >= 4
# Out:
# True

# %%
[1, 5] > [1, 3]
# Out:
# True

# %%
{2, 4, 6} > {6, 2}
# Out:
# True

# %%
"ra" > "me"
# Out:
# True

# %%
True > False
# Out:
# True

# %% [markdown]
# ### Operadores lógicos

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
age = 55

# %%
(age >= 18) and (age <= 65)
# Out:
# True

# %%
(age < 18) and (age[1] == 5)
# Out:
# False

# %%
not []
# Out:
# True

# %% [markdown]
# ### Operadores de pertenencia

# %%
4 in [2, 5]
# Out:
# False

# %%
4 in [2, 4]
# Out:
# True

# %%
"a" in "Madrid"
# Out:
# True

# %%
"m" in "Madrid"
# Out:
# False

# %%
"a" in {"a": 1, "b": 2}
# Out:
# True

# %%
1 in {"a": 1, "b": 2}
# Out:
# False

# %% [markdown]
# ### Operadores de identidad

# %%
a = [1, 2]
b = [1, 2]

# %%
a is b
# Out:
# False

# %%
a = [1, 2]
b = a

# %%
a is b
# Out:
# True

# %% [markdown]
# ### Operadores a nivel de bit

# %%
5 & 3
# Out:
# 1

# %%
5 | 3
# Out:
# 7

# %%
5 ^3
# Out:
# 6

# %%
~5
# Out:
# -6

# %%
1 << 2
# Out:
# 4

# %%
23 >> 2
# Out:
# 5

# %% [markdown]
# ### Operadores de tipos estructurados

# %%
"a" * 3
# Out:
# 'aaa'

# %%
"a" + "b"
# Out:
# 'ab'

# %%
a = [1, 2]
b = [3, 4]

# %%
a + b
# Out:
# [1, 2, 3, 4]

# %%
[1, 2] * 3
# Out:
# [1, 2, 1, 2, 1, 2]

# %%
{1, 2} | {2, 3}
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Operadores de asignación compuesta

# %%
a = 23
a = a + 2
a
# Out:
# 25

# %%
a = 23
a += 2
a
# Out:
# 25

# %%
a = 3
a *= 2
a
# Out:
# 6

# %% [markdown]
# ### Precedencia de operadores

# %%
2 + 3 * 4
# Out:
# 14

# %%
(2 + 3) * 4
# Out:
# 20
