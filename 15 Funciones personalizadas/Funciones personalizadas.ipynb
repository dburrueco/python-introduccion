# %%
def saluda():
    pass

# %%
saluda()

# %%
def saluda():
    print("Hola")

# %%
saluda()
# Out:
# Hola

# %%
saluda()
# Out:
# Hola

# %%
def saluda(name):
    print("Hola", name)

saluda("Daniel")
# Out:
# Hola Daniel

# %%
saluda("James")
# Out:
# Hola James

# %%
saluda("Daniel")
# Out:
# Hola Daniel

# %%
def suma(a, b):
    print(a + b)

suma(3, 8)
# Out:
# 11

# %%
resultado = suma(3, 8)
# Out:
# 11

# %%
type(resultado)
# Out:
# NoneType

# %%
def suma(a, b):
    return a + b

# %%
suma(3, 8)
# Out:
# 11

# %%
resultado = suma(3, 8)

# %%
def resultado(nota):
    if nota >= 5:
        return "Aprobado"
    else:
        return "Suspenso"

# %%
resultado(3)
# Out:
# 'Suspenso'

# %%
def suma_uno(numero):
    incremento = 1
    return numero + incremento

# %%
suma_uno(6)
# Out:
# 7

# %%
incremento
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 incremento
#
# NameError: name 'incremento' is not defined
