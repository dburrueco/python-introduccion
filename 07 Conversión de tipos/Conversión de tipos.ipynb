# %%
3 + 1.0
# Out:
# 4.0

# %% [markdown]
# ### int

# %%
int(3.99)
# Out:
# 3

# %%
int(-3.99)
# Out:
# -3

# %%
int(True)
# Out:
# 1

# %%
int("17")
# Out:
# 17

# %%
int("1001", base = 2)
# Out:
# 9

# %% [markdown]
# ### float

# %%
float(5)
# Out:
# 5.0

# %%
float("1.7")
# Out:
# 1.7

# %%
float("7")
# Out:
# 7.0

# %%
float(True)
# Out:
# 1.0

# %%
float("inf")
# Out:
# inf

# %%
float("-inf")
# Out:
# -inf

# %%
float("nan")
# Out:
# nan

# %% [markdown]
# ### str

# %%
str(42)
# Out:
# '42'

# %%
str(3.14)
# Out:
# '3.14'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str([1, 2, 3])
# Out:
# '[1, 2, 3]'

# %% [markdown]
# ### bool

# %%
bool(0)
# Out:
# False

# %%
bool(0 + 0j)
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool(5)
# Out:
# True

# %%
bool(-7.3)
# Out:
# True

# %%
bool("Python")
# Out:
# True

# %%
bool([1, 4])
# Out:
# True

# %% [markdown]
# ### list

# %%
list((1, 2))
# Out:
# [1, 2]

# %%
list({1, 2})
# Out:
# [1, 2]

# %%
list({"a": 1, "b": 2})
# Out:
# ['a', 'b']

# %%
list("Python")
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
a = (1, 2)
b = list(a)

# %%
a
# Out:
# (1, 2)

# %%
b
# Out:
# [1, 2]

# %% [markdown]
# ### tuple

# %%
tuple([1, 2])
# Out:
# (1, 2)

# %%
tuple({1, 2})
# Out:
# (1, 2)

# %%
tuple({"a": 1, "b": 2})
# Out:
# ('a', 'b')

# %%
tuple("Python")
# Out:
# ('P', 'y', 't', 'h', 'o', 'n')

# %% [markdown]
# ### set

# %%
set([2, 4, 1, 4])
# Out:
# {1, 2, 4}

# %% [markdown]
# ### dict

# %%
dict([("a", 1), ("b", 2)])
# Out:
# {'a': 1, 'b': 2}

# %%
dict(a = 1, b = 2)
# Out:
# {'a': 1, 'b': 2}
