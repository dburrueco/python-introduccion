# %%
for number in [1, 2, 3, 4, 5]:
    print("Python")
# Out:
# Python
# Python
# Python
# Python
# Python

# %%
for number in [1, 2, 3, 4, 5]:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
range(3, 7)
# Out:
# range(3, 7)

# %%
list(range(3, 7))
# Out:
# [3, 4, 5, 6]

# %%
list(range(0, 5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
for number in range(5):
    print(number)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
colores = ["verde", "azul", "amarillo"]

# %%
for color in colores:
    print(color)
# Out:
# verde
# azul
# amarillo

# %%
for letra in "Python":
    print(letra)
# Out:
# P
# y
# t
# h
# o
# n
