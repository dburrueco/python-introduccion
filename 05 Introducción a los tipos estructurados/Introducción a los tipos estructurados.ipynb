# %% [markdown]
# ### Listas

# %%
a = [1, 2, 3]
type(a)
# Out:
# list

# %%
a = [2, "Python", True]

# %%
a[0]
# Out:
# 2

# %%
a[1]
# Out:
# 'Python'

# %%
a[-1]
# Out:
# True

# %%
a[-2]
# Out:
# 'Python'

# %%
a
# Out:
# [2, 'Python', True]

# %%
a = ["a", "b", [7, 8]]

# %%
a[0]
# Out:
# 'a'

# %%
a[1]
# Out:
# 'b'

# %%
a[2]
# Out:
# [7, 8]

# %%
a[2][0]
# Out:
# 7

# %% [markdown]
# ### Tuplas

# %%
b = (2, "Python", True)
type(b)
# Out:
# tuple

# %%
b[1]
# Out:
# 'Python'

# %%
b[-2]
# Out:
# 'Python'

# %% [markdown]
# ### Conjuntos

# %%
c = {2, "Python", True}
type(c)
# Out:
# set

# %% [markdown]
# ### Diccionarios

# %%
meses = {"enero": 31, "febrero": 28, "marzo": 31}
type(meses)
# Out:
# dict

# %%
meses["enero"]
# Out:
# 31
