# %% [markdown]
# # Jupyter

# %%
a = 7

# %% [markdown]
# ### Jupyter

# %% [markdown]
# #### Jupyter

# %%
print(a)
# Out:
# 7

# %%
print(a)
# Out:
# 7

# %%
b = 4
print(a + b)
# Out:
# 11

# %% [markdown]
# **Python** for *Data Science*
